# %% [markdown]
# # Pipe 4
#
# Notebook contains scripts for visualizing kinematic data.
#
# Inputs files must be `.csv` file output by `analysis.ipynb`.
#
# _Note that these `.csv` files are different from those generated by `rtklib-pos-to-csv.ipynb` as they have different headers._

# %%
import plotly.express as px
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import splrep, splprep, splev, BSpline
import csv
# %matplotlib notebook

from pyubx2 import UBXReader

# %%
# NOTE! this value should match what is in analysis.ipynb

CALC_CSV_HEADER = [
    "timestamp", # a datetime object (as a string)
    "fix_type",
    "latitude",
    "longitude",
    "ground_speed_raw", # m/s
    "ground_speed_processed", # m/s, currently the same value as raw
    "acceleration",
    "altitude", # meters
    "horizontal_accuracy",
    "vertical_accuracy",
    "speed_accuracy"
 ]

INPUT_FILEPATH = "/home/delaynie/Documents/rtklib-workspace/cmubuggy-datalogger/data/calc-csv/"

# %%
# Takes in a CSV from the previous pipe
def generate_dataframe(filepath):
    with open(filepath, 'r') as f:
        return pd.DataFrame.from_dict(list(csv.DictReader(f)))

# %%
def plot_trace(df):
    layers = [{"below": "traces",
               "sourcetype": "raster",
               "source": ["https://imagery.pasda.psu.edu/arcgis/rest/services/pasda/PEMAImagery2018_2020/MapServer/WMTS/tile/1.0.0/pasda_PEMAImagery2018_2020/default/default028mm/{z}/{y}/{x}.png"]}]

    fig = px.scatter_mapbox(df,
                            lat="latitude", lon="longitude",
                            color="ground_speed_processed",
                            hover_data=["horizontal_accuracy",
                                        "speed_accuracy",
                                        "altitude",
                                        "timestamp"],
                            zoom=15, size_max=18,
                            height=400, width=800)

    fig.update_layout(
        mapbox_style="white-bg",
        mapbox_layers=layers
    )
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()

# %%
df = generate_dataframe(f"{INPUT_FILEPATH}output1.csv")

# %%
df
# Out:
#                        timestamp fix_type      latitude      longitude  \
# 0     2023/03/24 17:48:23.700000        2  40.449071045  -79.951963274
# 1     2023/03/24 17:48:23.800000        2  40.449067278  -79.951961548
# 2     2023/03/24 17:48:23.900000        2  40.449063422  -79.951959922
# 3     2023/03/24 17:48:24.000000        2  40.449059561  -79.951958478
# 4     2023/03/24 17:48:24.100000        2  40.449055752  -79.951957148
# ...                          ...      ...           ...            ...
# 3991  2023/03/24 17:55:05.100000        1  40.441451013  -79.946365905
# 3992  2023/03/24 17:55:05.200000        1  40.441451475  -79.946364396
# 3993  2023/03/24 17:55:05.300000        1  40.441452015  -79.946362862
# 3994  2023/03/24 17:55:05.400000        1  40.441452527  -79.946361255
# 3995  2023/03/24 17:55:05.500000        1  40.441453032  -79.946359711
#
#      ground_speed_raw ground_speed_processed         acceleration  altitude  \
# 0              4.6326                 4.6326                    0  259.9567
# 1              4.4319                 4.4319  -2.0070000000000032   259.955
# 2              4.4985                 4.4985   0.6660000000000021  259.9619
# 3              4.4589                 4.4589  -0.3960000000000008  259.9667
# 4              4.3775                 4.3775  -0.8139999999999947  259.9715
# ...               ...                    ...                  ...       ...
# 3991           1.2586                 1.2586    2.205999999999999  251.9357
# 3992           1.3792                 1.3792   1.2060000000000004  251.9462
# 3993            1.433                  1.433   0.5380000000000007  251.9594
# 3994           1.4772                 1.4772  0.44200000000000017  251.9584
.44843750940.4484351740.44843283440.44843054540.44842833640.4484261340.44842392140.44842176640.44841958640.44841746740.44841539140.44841343840.44841152340.44840959140.44840764840.4484057840.44840394640.44840212540.44840041340.44839874540.44839715240.44839565840.44839421140.44839274540.44839129340.44838988840.44838849740.44838719340.44838600140.44838502440.44838429540.44838366540.44838326540.44838306740.44838303140.4483830240.44838337140.44838356140.44838373540.44838385840.44838393940.44838394440.44838390540.44838386240.44838381940.44838375240.44838366240.44838356540.44838344840.44838333640.44838324240.44838317640.44838313640.44838310340.44838306340.44838297740.44838286540.44838269540.44838242740.44838200540.4483814340.44838067740.44837968840.44837842940.44837693340.44837534740.44837381640.44837238940.44837111340.4483698540.44836858640 ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plot_trace(df)
#
# Cell In[23], line 6, in plot_trace(df)
#       1 def plot_trace(df):
#       2     layers = [{"below": "traces",
#       3                "sourcetype": "raster",
#       4                "source": ["https://imagery.pasda.psu.edu/arcgis/rest/services/pasda/PEMAImagery2018_2020/MapServer/WMTS/tile/1.0.0/pasda_PEMAImagery2018_2020/default/default028mm/{z}/{y}/{x}.png"]}]
# ----> 6     fig = px.scatter_mapbox(df,
#       7                             lat="latitude", lon="longitude",
#       8                             color="ground_speed_processed",
#       9                             hover_data=["horizontal_accuracy",
#      10                                         "speed_accuracy",
#      11                                         "altitude",
#      12                                         "timestamp"],
#      13                             zoom=15, size_max=18,
#      14                             height=400, width=800)
#      16     fig.update_layout(
#      17         mapbox_style="white-bg",
#      18         mapbox_layers=layers
#      19     )
#      20     fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_chart_types.py:1247, in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1214 def scatter_mapbox(
#    1215     data_frame=None,
#    1216     lat=None,
#    (...)
#    1241     height=None,
#    1242 ) -> go.Figure:
#    1243     """
#    1244     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1245     symbol mark on a Mapbox map.
#    1246     """
# -> 1247     return make_figure(args=locals(), constructor=go.Scattermapbox)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:2290, in make_figure(args, constructor, trace_patch, layout_patch)
#    2286         trendline_rows.append(dict(px_fit_results=fit_results))
#    2288 fig._px_trendlines = pd.DataFrame(trendline_rows)
# -> 2290 configure_axes(args, constructor, fig, orders)
#    2291 configure_animation_controls(args, constructor, fig)
#    2292 return fig
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:542, in configure_axes(args, constructor, fig, orders)
#     540     configurators[c] = configure_cartesian_axes
#     541 if constructor in configurators:
# --> 542     configurators[constructor](args, fig, orders)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:730, in configure_mapbox(args, fig, orders)
#     727 center = args["center"]
#     728 if not center and "lat" in args and "lon" in args:
#     729     center = dict(
# --> 730         lat=args["data_frame"][args["lat"]].mean(),
#     731         lon=args["data_frame"][args["lon"]].mean(),
#     732     )
#     733 fig.update_mapboxes(
#     734     accesstoken=MAPBOX_TOKEN,
#     735     center=center,
#     736     zoom=args["zoom"],
#     737     style=args["mapbox_style"],
#     738 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert